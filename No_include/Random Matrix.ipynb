# %%
import numpy as np
import matplotlib.pylab as plt

# %%
N=200
eigen_values=np.array([])
for i in range(1000):
    print(i,end="\r")
    real=np.random.normal(0,1,(N,N))
    imaginary= np.random.normal(0,1,(N,N))
    A=real+ 1j *imaginary
    B=A+A.conj().T
    w=np.linalg.eigvals(B)
    eigen_values=np.append(eigen_values,w)
# Out:
# 999

# %%
plt.hist(np.real(eigen_values),bins=100,density=True)
plt.show()

# %%
nmax =100000
Fib = [0,1]
for k in range(2, nmax):   
    Fib.append(Fib[-1] + Fib[-2])
N = 8
FibmodN = [F % N for F in Fib]
print(FibmodN)
# Out:
# [0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0, 1, 1, 2, 3, 5, 0, 5, 5, 2, 7, 1, 0,  ...

# %%
def fib(n):
    if n==0:
        return 0
    elif n==1:
        return 1
    else:
        return fib(n-1) + fib(n-2)

# %%
# Out:
# 102334155

# %%
try:
    import pygame
    from pygame import surfarray
    from pygame.locals import *
    import copy
except ImportError:
    raise ImportError('Error Importing Pygame/surfarray/time module')

# Function to load a file, and return an array of pixels
def getPixelArray(filename):
    image = pygame.image.load(filename)
    return pygame.surfarray.array3d(image)

# To get the new coordinates from the old coordinates
def iterate(x, y, N):
    return (y % N, (x + y) % N)

pixels = getPixelArray('cat.jpg')   # choose the image to use
pix2 = copy.copy(pixels)   # Copy the pixel array

size = pixels.shape[:2]   # Find out the size of the image
if not size[0] == size[1]:
    print ("I was expecting a square image!")

N = size[0]   # The side length of the square
print(N)
size = [2*i for i in size]   # We will zoom in by a factor of 2.
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 112

# %%
# Create the display window
screen = pygame.display.set_mode(size) 
pygame.display.set_caption("The Fibonacci Feline Map")
pygame.display.flip()

interval = 300   # How long to wait between frames, in milliseconds

done = False
while not done:
    for e in pygame.event.get():
        if e.type == QUIT:
            done = True    # exit gracefully

    # loop over the pixel coordinates
    for i in range(pixels.shape[0]):
        for j in range(pixels.shape[1]):
            # use the Fibonacci rule for moving the pixels around
            pt = iterate(i, j, N)
            # copy each pixel into the new array
            pix2[i, j, :] = pixels[pt[0], pt[1], :]
            
    pixels = copy.copy(pix2)   # make a copy, for the next loop
    mysurf = surfarray.make_surface(pixels)   # display the scrambled image
    pygame.transform.scale2x(mysurf, screen)
    pygame.display.flip()
    pygame.time.delay(interval)  # wait for "interval" milliseconds

pygame.quit()

# %%
import numpy as np

# %%
a=open("cat.jpg")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import time
img=mpimg.imread('cat.jpg')



new_img=img.copy()



N=112
def Fib_map(x, y, N):
    return ((y) % N, (x + y) % N)


from IPython.display import clear_output
for _ in range(1000):
    time.sleep(0.1)
    plt.imshow(img)
    plt.show()
    clear_output(wait=True)
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            pixel = Fib_map(i, j, N)
            #pixel=gingerbreadman_map(i,j)
            #print(new_img[i,j,:],img[pixel[0],pixel[1],:])
            new_img[i,j,:]=img[pixel[0],pixel[1],:]
    img=new_img.copy()

# %%
plt.imshow(new_img)

# %%
for i in range(10):
    clear_output()
    print(i)
# Out:
# 9

# %%
def gingerbreadman_map(x,y):
    return (1-y+np.abs(x),x)

# %%
a=0
b=1
values=[a,b]
for i in range(30000):
    tmp=1-1.4*b**2+0.3*a
    values.append(tmp)
    a=b
    b=tmp

# %%
plt.plot(values[1:],values[:-1],".k")

# %%
all_a=np.linspace(1,1.5,500)
values=[]
alphas=[]
for i in all_a:   
    for test in range(50):
        H_n_1=0.63
        H_n_2=0.18
        for _ in range(300):
            tmp=1-i*(H_n_1**2) + 0.3*H_n_2
            H_n_2=H_n_1
            H_n_1=tmp
        values.append(tmp)
        alphas.append(i)
# Out:
# C:\Users\jamontana\AppData\Local\conda\conda\envs\TensorFlow\lib\site-packages\ipykernel_launcher.py:9: RuntimeWarning: overflow encountered in double_scalars
#   if __name__ == '__main__':

# %%
plt.plot(alphas,values,".k")

# %%
first=np.random.normal(-2,1,10000)
second=np.random.normal(2,1,10000)

# %%
plt.hist(first*second,bins=50)
plt.hist(first,bins=50)
plt.hist(second,bins=50)
# Out:
# (array([  2.,   0.,   1.,   0.,   0.,   1.,   1.,   6.,  15.,  16.,  22.,
#          41.,  48.,  64.,  84., 121., 154., 230., 241., 300., 357., 412.,
#         473., 581., 596., 653., 605., 653., 578., 584., 542., 503., 422.,
#         377., 290., 262., 209., 174., 114.,  79.,  54.,  45.,  33.,  13.,
#          17.,  11.,   4.,   6.,   4.,   2.]),
#  array([-2.20673291, -2.05054216, -1.89435142, -1.73816067, -1.58196993,
#         -1.42577918, -1.26958844, -1.11339769, -0.95720695, -0.8010162 ,
#         -0.64482546, -0.48863471, -0.33244397, -0.17625322, -0.02006248,
#          0.13612827,  0.29231902,  0.44850976,  0.60470051,  0.76089125,
#          0.917082  ,  1.07327274,  1.22946349,  1.38565423,  1.54184498,
#          1.69803572,  1.85422647,  2.01041721,  2.16660796,  2.3227987 ,
#          2.47898945,  2.63518019,  2.79137094,  2.94756168,  3.10375243,
#          3.25994317,  3.41613392,  3.57232466,  3.72851541,  3.88470615,
#          4.0408969 ,  4.19708764,  4.35327839,  4.50946913,  4.66565988,
#          4.82185062,  4.97804137,  5.13423211,  5.29042286,  5.4466136 ,
#          5.60280435]),
#  <a list of 50 Patch objects>)
